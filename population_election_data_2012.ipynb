# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import os
import csv
from census import Census
from us import states
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')
# Census API Key
# from config import api_key

# %%
temp_df = pd.read_csv("Resources/population2000-2016ALL.csv")
election_data_2012 = pd.read_csv("Resources/election_data2012.csv")
len(temp_df)
# Out:
# 3144

# %%
temp_df["County"] = temp_df.County.str.replace('County','').str.strip()
temp_df["Location"] = temp_df.Location.str.replace('County','').str.strip()
# to check the value and length for the first row
print(temp_df["County"][0], len(temp_df["County"][0]), temp_df["Location"][0], len(temp_df["Location"][0]))
temp_df
# Out:
# Autauga 7 Alabama, Autauga 16
#         State      County             Location    2000    2001    2002  \
# 0     Alabama     Autauga     Alabama, Autauga   44021   44889   45909
# 1     Alabama     Baldwin     Alabama, Baldwin  141342  144875  147957
# 2     Alabama     Barbour     Alabama, Barbour   29015   28863   28653
# 3     Alabama        Bibb        Alabama, Bibb   19913   21028   21199
# 4     Alabama      Blount      Alabama, Blount   51107   51845   52551
# ...       ...         ...                  ...     ...     ...     ...
# 3139  Wyoming  Sweetwater  Wyoming, Sweetwater   37552   36899   37428
# 3140  Wyoming       Teton       Wyoming, Teton   18381   18653   18837
# 3141  Wyoming       Uinta       Wyoming, Uinta   19666   19413   19587
# 3142  Wyoming    Washakie    Wyoming, Washakie    8252    8068    7988
# 3143  Wyoming      Weston      Wyoming, Weston    6627    6487    6578
#
#         2003    2004    2005    2006    2007    2008    2009     2010  \
# ...

# %%
print(len(election_data_2012))
# Out:
# 6308

# %%
temp_df['Location'] = (temp_df.State +", " +temp_df.County)
temp_df.head()
# Out:
#      State   County          Location    2000    2001    2002    2003    2004  \
# 0  Alabama  Autauga  Alabama, Autauga   44021   44889   45909   46800   48366
# 1  Alabama  Baldwin  Alabama, Baldwin  141342  144875  147957  151509  156266
# 2  Alabama  Barbour  Alabama, Barbour   29015   28863   28653   28594   28287
# 3  Alabama     Bibb     Alabama, Bibb   19913   21028   21199   21399   21721
# 4  Alabama   Blount   Alabama, Blount   51107   51845   52551   53457   54124
#
#      2005    2006    2007    2008    2009     2010     2011     2012     2013  \
# 0   49676   51328   52405   53277   54135   54,773   55,227   54,954   54,727
# 1  162183  168121  172404  175827  179406  183,112  186,558  190,145  194,885
# 2   28027   27861   27757   27808   27657   27,327   27,341   27,169   26,937
# 3   22042   22099   22438   22705   22941   22,870   22,745   22,667   22,521
# 4   54624   55485   56240   57055   57341   57,376   57,560   57,580   57,619
#
# ...

# %%
# Finding duplicate rows by Location
dup_df = temp_df[temp_df['Location'].duplicated()]
len(dup_df)
# Out:
# 0

# %%
election_data_2012['Location'] = (election_data_2012.state +", "+election_data_2012.county)
election_data_2012
# Out:
#       year    state state_code       county     candidate       party  \
# 0     2012  Alabama         AL      Autauga  Barack Obama    democrat
# 1     2012  Alabama         AL      Autauga   Mitt Romney  republican
# 2     2012  Alabama         AL      Baldwin  Barack Obama    democrat
# 3     2012  Alabama         AL      Baldwin   Mitt Romney  republican
# 4     2012  Alabama         AL      Barbour  Barack Obama    democrat
# ...    ...      ...        ...          ...           ...         ...
# 6303  2012   Alaska         AK  District 38   Mitt Romney  republican
# 6304  2012   Alaska         AK  District 39  Barack Obama    democrat
# 6305  2012   Alaska         AK  District 39   Mitt Romney  republican
# 6306  2012   Alaska         AK  District 40  Barack Obama    democrat
# 6307  2012   Alaska         AK  District 40   Mitt Romney  republican
#
#       candidate_votes  total_votes             Location
# 0              6363.0        23932     Alabama, Autauga
# ...

# %%
election_data_2012["party"].unique()
# Out:
# array(['democrat', 'republican'], dtype=object)

# %%
# create df for unique parties 
democrat_2012 = election_data_2012.loc[election_data_2012["party"] == 'democrat']
democrat_2012
# Out:
#       year    state state_code       county     candidate     party  \
# 0     2012  Alabama         AL      Autauga  Barack Obama  democrat
# 2     2012  Alabama         AL      Baldwin  Barack Obama  democrat
# 4     2012  Alabama         AL      Barbour  Barack Obama  democrat
# 6     2012  Alabama         AL         Bibb  Barack Obama  democrat
# 8     2012  Alabama         AL       Blount  Barack Obama  democrat
# ...    ...      ...        ...          ...           ...       ...
# 6298  2012   Alaska         AK  District 36  Barack Obama  democrat
# 6300  2012   Alaska         AK  District 37  Barack Obama  democrat
# 6302  2012   Alaska         AK  District 38  Barack Obama  democrat
# 6304  2012   Alaska         AK  District 39  Barack Obama  democrat
# 6306  2012   Alaska         AK  District 40  Barack Obama  democrat
#
#       candidate_votes  total_votes             Location
# 0              6363.0        23932     Alabama, Autauga
# ...

# %%
republican_2012 = election_data_2012.loc[election_data_2012["party"] == 'republican']
republican_2012
# Out:
#       year    state state_code       county    candidate       party  \
# 1     2012  Alabama         AL      Autauga  Mitt Romney  republican
# 3     2012  Alabama         AL      Baldwin  Mitt Romney  republican
# 5     2012  Alabama         AL      Barbour  Mitt Romney  republican
# 7     2012  Alabama         AL         Bibb  Mitt Romney  republican
# 9     2012  Alabama         AL       Blount  Mitt Romney  republican
# ...    ...      ...        ...          ...          ...         ...
# 6299  2012   Alaska         AK  District 36  Mitt Romney  republican
# 6301  2012   Alaska         AK  District 37  Mitt Romney  republican
# 6303  2012   Alaska         AK  District 38  Mitt Romney  republican
# 6305  2012   Alaska         AK  District 39  Mitt Romney  republican
# 6307  2012   Alaska         AK  District 40  Mitt Romney  republican
#
#       candidate_votes  total_votes             Location
# 1             17379.0        23932     Alabama, Autauga
# ...

# %%
# collecting required columns...
republican_2012 = republican_2012[['total_votes', 'candidate_votes', 'Location']]
republican_2012.columns = ['total_votes', '2012_republican_votes', 'Location']
republican_2012.head()
democrat_2012 = democrat_2012[['total_votes', 'candidate_votes', 'Location']]
democrat_2012.columns = ['total_votes', '2012_democrat_votes', 'Location']
democrat_2012.head()
# Out:
#    total_votes  2012_democrat_votes          Location
# 0        23932               6363.0  Alabama, Autauga
# 2        85338              18424.0  Alabama, Baldwin
# 4        11509               5912.0  Alabama, Barbour
# 6         8420               2202.0     Alabama, Bibb
# 8        24006               2970.0   Alabama, Blount

# %%
# Finding # of rows in both df's to make sure sum match with parent df
print(len(republican_2012['Location'].unique()), len(democrat_2012['Location'].unique()))
# Out:
# 3149 3149

# %%
# Finding duplicate rows by Location
dup_df = republican_2012[republican_2012['Location'].duplicated()]
dup_df
# Out:
#       total_votes  2012_republican_votes            Location
# 5775         2805                 1527.0   Virginia, Bedford
# 5793        11629                 4775.0   Virginia, Fairfax
# 5797         4360                 1496.0  Virginia, Franklin
# 5833        97569                20050.0  Virginia, Richmond
# 5835        40155                14991.0   Virginia, Roanoke

# %%
# pulling duplicate rows for Location
t = republican_2012.loc[(republican_2012['Location'] == 'Virginia, Bedford') | (republican_2012['Location'] == 'Virginia, Fairfax') | (republican_2012['Location'] == 'Virginia, Franklin') | (republican_2012['Location'] == 'Virginia, Richmond') | (republican_2012['Location'] == 'Virginia, Roanoke')]
t1 = t.sort_values(['Location'])
print(len(t1))
t1
# Out:
# 10
#       total_votes  2012_republican_votes            Location
# 5601        37425                26679.0   Virginia, Bedford
# 5775         2805                 1527.0   Virginia, Bedford
# 5639       529287               206773.0   Virginia, Fairfax
# 5793        11629                 4775.0   Virginia, Fairfax
# 5647        26707                16718.0  Virginia, Franklin
# 5797         4360                 1496.0  Virginia, Franklin
# 5733         3770                 2160.0  Virginia, Richmond
# 5833        97569                20050.0  Virginia, Richmond
# 5735        51217                31624.0   Virginia, Roanoke
# 5835        40155                14991.0   Virginia, Roanoke

# %%
# Data cleaning - deleting rows that are not supposed to be counties.. (did a manual check)
ind = republican_2012.loc[((republican_2012['Location'] == 'Virginia, Bedford') & (republican_2012['total_votes'] == 2805) ) | ((republican_2012['Location'] == 'Virginia, Fairfax') & (republican_2012['total_votes'] == 11629) )  | ((republican_2012['Location'] == 'Virginia, Franklin') & (republican_2012['total_votes'] == 4360) ) | ((republican_2012['Location'] == 'Virginia, Richmond') & (republican_2012['total_votes'] == 97569) ) | ((republican_2012['Location'] == 'Virginia, Roanoke') & (republican_2012['total_votes'] == 40155) )].index
ind      # make sure before deletion...
republican_2012.drop(ind, inplace=True)
ind = democrat_2012.loc[((democrat_2012['Location'] == 'Virginia, Bedford') & (democrat_2012['total_votes'] == 2805) ) | ((democrat_2012['Location'] == 'Virginia, Fairfax') & (democrat_2012['total_votes'] == 11629) )  | ((democrat_2012['Location'] == 'Virginia, Franklin') & (democrat_2012['total_votes'] == 4360) ) | ((democrat_2012['Location'] == 'Virginia, Richmond') & (democrat_2012['total_votes'] == 97569) ) | ((democrat_2012['Location'] == 'Virginia, Roanoke') & (democrat_2012['total_votes'] == 40155) )].index
democrat_2012.drop(ind, inplace=True)

# %%
print(len(republican_2012), len(democrat_2012), len(temp_df))
# Out:
# 3149 3149 3144

# %%
election_parties_2012 = pd.merge(republican_2012,democrat_2012, on='Location')
election_parties_2012 = election_parties_2012[['Location','total_votes_x','2012_republican_votes','2012_democrat_votes']]
election_parties_2012.columns = ['Location','total_votes','2012_republican_votes','2012_democrat_votes']
election_parties_2012
# Out:
#                  Location  total_votes  2012_republican_votes  \
# 0        Alabama, Autauga        23932                17379.0
# 1        Alabama, Baldwin        85338                66016.0
# 2        Alabama, Barbour        11509                 5550.0
# 3           Alabama, Bibb         8420                 6132.0
# 4         Alabama, Blount        24006                20757.0
# ...                   ...          ...                    ...
# 3144  Alaska, District 36         4972                 1386.0
# 3145  Alaska, District 37         4335                 1517.0
# 3146  Alaska, District 38         6814                 2259.0
# 3147  Alaska, District 39         6560                 2566.0
# 3148  Alaska, District 40         4235                 1347.0
#
#       2012_democrat_votes
# 0                  6363.0
# 1                 18424.0
# 2                  5912.0
# 3                  2202.0
# 4                  2970.0
# ...                   ...
# 3144               3341.0
# ...

# %%
# identifiy mismatch records ....and review before deletion
pop1 = election_parties_2012.merge(temp_df, on='Location', how='left', indicator=True)
pop1
# Out:
#                  Location  total_votes  2012_republican_votes  \
# 0        Alabama, Autauga        23932                17379.0
# 1        Alabama, Baldwin        85338                66016.0
# 2        Alabama, Barbour        11509                 5550.0
# 3           Alabama, Bibb         8420                 6132.0
# 4         Alabama, Blount        24006                20757.0
# ...                   ...          ...                    ...
# 3144  Alaska, District 36         4972                 1386.0
# 3145  Alaska, District 37         4335                 1517.0
# 3146  Alaska, District 38         6814                 2259.0
# 3147  Alaska, District 39         6560                 2566.0
# 3148  Alaska, District 40         4235                 1347.0
#
#       2012_democrat_votes    State   County      2000      2001      2002  \
# 0                  6363.0  Alabama  Autauga   44021.0   44889.0   45909.0
# ...

# %%
pop2 = pop1.loc[pop1['_merge'] == 'left_only']
print(len(pop2))
# pop2['Location'].unique()
# Out:
# 148

# %%
#  cleaned data for 2012
population_election_data_2012 = pop1.loc[pop1['_merge'] == 'both']
print(len(population_election_data_2012))
population_election_data_2012 = population_election_data_2012[['Location','2012','total_votes','2012_democrat_votes','2012_republican_votes']]
# Out:
# 3001

# %%
del population_election_data_2012['2012']
population_election_data_2012
# Out:
#                  Location  total_votes  2012_democrat_votes  \
# 0        Alabama, Autauga        23932               6363.0
# 1        Alabama, Baldwin        85338              18424.0
# 2        Alabama, Barbour        11509               5912.0
# 3           Alabama, Bibb         8420               2202.0
# 4         Alabama, Blount        24006               2970.0
# ...                   ...          ...                  ...
# 3104  Wyoming, Sweetwater        16895               4774.0
# 3105       Wyoming, Teton        11464               6213.0
# 3106       Wyoming, Uinta         8539               1628.0
# 3107    Wyoming, Washakie         3944                794.0
# 3108      Wyoming, Weston         3359                422.0
#
#       2012_republican_votes
# 0                   17379.0
# 1                   66016.0
# 2                    5550.0
# 3                    6132.0
# 4                   20757.0
# ...                     ...
# 3104                11428.0
# ...

# %%
population_election_data_2012.to_csv(r'Resources/FOR_JINHO_2012.csv', index=False, header=True)
