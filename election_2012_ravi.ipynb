# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import os
import csv
from census import Census
from us import states
from pprint import pprint
# Census API Key
# from config import api_key

# %%
temp_df = pd.read_csv("Resources/election_all.csv")
temp_df.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          4942.0       17208  20191203
# 1  republican         11993.0       17208  20191203
# 2       green           160.0       17208  20191203
# 3         NaN           113.0       17208  20191203
# 4    democrat         13997.0       56480  20191203

# %%
temp_df1 = temp_df[['year', 'state', 'state_po', 'county', 'candidate','party', 'candidatevotes', 'totalvotes']]
temp_df1.columns = ['year', 'state', 'state_code', 'county', 'candidate', 'party','candidate_votes', 'total_votes']
temp_df2 = temp_df1.loc[temp_df1["year"] == 2012]
temp_df2
# Out:
#        year    state state_code       county     candidate       party  \
# 31166  2012  Alabama         AL      Autauga  Barack Obama    democrat
# 31167  2012  Alabama         AL      Autauga   Mitt Romney  republican
# 31168  2012  Alabama         AL      Autauga         Other         NaN
# 31169  2012  Alabama         AL      Baldwin  Barack Obama    democrat
# 31170  2012  Alabama         AL      Baldwin   Mitt Romney  republican
# ...     ...      ...        ...          ...           ...         ...
# 50396  2012   Alaska         AK  District 40   Mitt Romney  republican
# 50397  2012   Alaska         AK  District 40         Other         NaN
# 50398  2012   Alaska        NaN  District 99  Barack Obama    democrat
# 50399  2012   Alaska        NaN  District 99   Mitt Romney  republican
# 50400  2012   Alaska        NaN  District 99         Other         NaN
#
#        candidate_votes  total_votes
# 31166           6363.0        23932
# 31167          17379.0        23932
# ...

# %%
election_data_2012 = temp_df2.dropna()
election_data_2012.to_csv(r'Resources/election_data2012.csv', index = False, header=True)
election_data_2012
# Out:
#        year    state state_code       county     candidate       party  \
# 31166  2012  Alabama         AL      Autauga  Barack Obama    democrat
# 31167  2012  Alabama         AL      Autauga   Mitt Romney  republican
# 31169  2012  Alabama         AL      Baldwin  Barack Obama    democrat
# 31170  2012  Alabama         AL      Baldwin   Mitt Romney  republican
# 31172  2012  Alabama         AL      Barbour  Barack Obama    democrat
# ...     ...      ...        ...          ...           ...         ...
# 50390  2012   Alaska         AK  District 38   Mitt Romney  republican
# 50392  2012   Alaska         AK  District 39  Barack Obama    democrat
# 50393  2012   Alaska         AK  District 39   Mitt Romney  republican
# 50395  2012   Alaska         AK  District 40  Barack Obama    democrat
# 50396  2012   Alaska         AK  District 40   Mitt Romney  republican
#
#        candidate_votes  total_votes
# 31166           6363.0        23932
# 31167          17379.0        23932
# ...
