# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import os
import csv
from census import Census
from us import states
from pprint import pprint
# Census API Key
# from config import api_key

# %%
temp_df = pd.read_csv("Resources/election_all.csv")
temp_df.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          4942.0       17208  20191203
# 1  republican         11993.0       17208  20191203
# 2       green           160.0       17208  20191203
# 3         NaN           113.0       17208  20191203
# 4    democrat         13997.0       56480  20191203

# %%
temp_df1 = temp_df[['year', 'state', 'state_po', 'county', 'candidate','party', 'candidatevotes', 'totalvotes']]
temp_df1.columns = ['year', 'state', 'state_code', 'county', 'candidate', 'party','candidate_votes', 'total_votes']
temp_df2 = temp_df1.loc[temp_df1["year"] == 2008]
temp_df2
# Out:
#        year    state state_code       county     candidate       party  \
# 21815  2008  Alabama         AL      Autauga  Barack Obama    democrat
# 21816  2008  Alabama         AL      Autauga   John McCain  republican
# 21817  2008  Alabama         AL      Autauga         Other         NaN
# 21818  2008  Alabama         AL      Baldwin  Barack Obama    democrat
# 21819  2008  Alabama         AL      Baldwin   John McCain  republican
# ...     ...      ...        ...          ...           ...         ...
# 50273  2008   Alaska         AK  District 40   John McCain  republican
# 50274  2008   Alaska         AK  District 40         Other         NaN
# 50275  2008   Alaska        NaN  District 99  Barack Obama    democrat
# 50276  2008   Alaska        NaN  District 99   John McCain  republican
# 50277  2008   Alaska        NaN  District 99         Other         NaN
#
#        candidate_votes  total_votes
# 21815           6093.0        23641
# 21816          17403.0        23641
# 21817            145.0        23641
# 21818          19386.0        81413
# 21819          61271.0        81413
# ...                ...          ...
# 50273           2686.0         5000
# 50274            177.0         5000
# 50275              NaN            0
# 50276              NaN            0
# 50277              NaN            0
#
# [9474 rows x 8 columns]

# %%
election_data_2008 = temp_df2.dropna()
election_data_2008.to_csv(r'Resources/election_data2008.csv', index = False, header=True)
election_data_2008
# Out:
#        year    state state_code       county     candidate       party  \
# 21815  2008  Alabama         AL      Autauga  Barack Obama    democrat
# 21816  2008  Alabama         AL      Autauga   John McCain  republican
# 21818  2008  Alabama         AL      Baldwin  Barack Obama    democrat
# 21819  2008  Alabama         AL      Baldwin   John McCain  republican
# 21821  2008  Alabama         AL      Barbour  Barack Obama    democrat
# ...     ...      ...        ...          ...           ...         ...
# 50267  2008   Alaska         AK  District 38   John McCain  republican
# 50269  2008   Alaska         AK  District 39  Barack Obama    democrat
# 50270  2008   Alaska         AK  District 39   John McCain  republican
# 50272  2008   Alaska         AK  District 40  Barack Obama    democrat
# 50273  2008   Alaska         AK  District 40   John McCain  republican
#
#        candidate_votes  total_votes
# 21815           6093.0        23641
# 21816          17403.0        23641
# 21818          19386.0        81413
# 21819          61271.0        81413
# 21821           5697.0        11630
# ...                ...          ...
# 50267           2056.0         4820
# 50269           2695.0         5184
# 50270           2323.0         5184
# 50272           2137.0         5000
# 50273           2686.0         5000
#
# [6308 rows x 8 columns]
